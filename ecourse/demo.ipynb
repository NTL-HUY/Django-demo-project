# %%
import os
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "ecourse.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

django.setup()

# Fix MySQL idle timeout
from django.db import connections
connections.close_all()

# %%
from courses.models import *
from django.contrib.auth.hashers import make_password

cat1 = Category.objects.create(name="Programming")
cat2 = Category.objects.create(name="AI")

# ---- Course ----
course1 = Course.objects.create(
    subject="Python Basic",
    description="Learn Python",
    category=cat1
)

course2 = Course.objects.create(
    subject="Deep Learning",
    description="Intro to DL",
    category=cat2
)

# ---- Tag ----
tag1 = Tag.objects.create(name="Beginner")
tag2 = Tag.objects.create(name="Neural Network")

# ---- Lesson ----
lesson = Lession.objects.create(
    subject="Intro Python",
    content="Variables and Types",
    course=course1
)

lesson1 = Lession.objects.create(
    subject="Intro Python",
    content="Variables and Types",
    course=course1
)

lesson1.tags.add(tag1)
lesson.tags.add(tag1, tag2)

# %%
from pprint import pprint

from django.db.models import QuerySet

from courses.models import *


Course.objects.all()
c = Course.objects.filter(active=True)
print(c.query)
# Out:
# SELECT `courses_course`.`id`, `courses_course`.`active`, `courses_course`.`created_date`, `courses_course`.`updated_date`, `courses_course`.`subject`, `courses_course`.`description`, `courses_course`.`image`, `courses_course`.`category_id` FROM `courses_course` WHERE `courses_course`.`active` = True
